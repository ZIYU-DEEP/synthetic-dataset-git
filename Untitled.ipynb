# %%
import numpy as np
import pandas as pd
import seaborn as sea
from pathlib import Path
# %config InlineBackend.figure_format='retina'

# %%
root = Path('./main/report/one_class')
semi_path = root / 'one_class_[1_-1_1]_[1_1_1]_[0.1]_[30]' / 'result_df.pkl'
un_path = root / 'one_class_unsupervised_[1_-1_1]_[]_[0.1]_[30]' / 'result_df.pkl'

# %%
semi_df = pd.read_pickle(semi_path)
un_df = pd.read_pickle(un_path)

# %%
ax1 = sea.distplot(un_df['scores'])

# %%
sea.distplot(semi_df['scores'])

# %%
len(semi_df)
# Out:
# 1320

# %%
len(un_df)
# Out:
# 1200
